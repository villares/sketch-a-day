# %%
for i in range(10):
    for j in range(10):
        square(i * 10, j * 10, 8)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
from itertools import product
ijs = product(range(10), repeat=2)
for i, j in ijs:
    square(i * 10, j * 10, 8)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
size(400, 400)
for x in range(20, width, 40):
    for y in range(20, height, 40):
        circle(x, y, 40)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>
