# %%
# %%python
#
# from itertools import product, combinations
#
# pos = list(product((0, 1, 2, 3), repeat=2))
#
# def draw_base():
#     for i, j in pos:
#         x = 100 + i * 100
#         y = 100 + j * 100
#         rect(x, y, 100, 100)
#
# def draw_combo(combo):
#     for i, j in combo:
#         x = 100 + i * 100
#         y = 100 + j * 100
#         push_matrix()
#         translate(x + 50, y + 50, 50)
#         box(100)
#         pop_matrix()
#
# combos = list(combinations(pos, 2))
# print(len(combos))
# Out:
# 120

# %%
size(600, 600, P3D) 
lights()
s = 12
scale(1/s)
    
x = y = 0
for combo in combos:
    no_fill()
    stroke(255, 0, 0)
    stroke_weight(s)
    draw_base() 
    fill(255)
    stroke(0)
    draw_combo(combo)
    translate(width, 0)
    x += width
    if x > width * s - width:
        translate(-width * s, height)
        x = 0
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7F59F4BF8520>
